# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import DenseNet121, ResNet50, VGG16, EfficientNetB7, InceptionV3
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, Conv3D, LayerNormalization, BatchNormalization, Dropout, MaxPooling3D, MaxPooling2D, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom
from keras.losses import CategoricalCrossentropy
from sklearn.model_selection import train_test_split
from tensorflow.keras.regularizers import l2
import keras.backend as k

# %%
k.clear_session()

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
from random import randint
import shutil

# Define paths
INPUT_DIR = '/kaggle/input/nitr-lowlight/nitr-lowlight'
DATADIR = '/kaggle/working/nitr-lowlight'

CATEGORIES = {
    'BBA': ['BBA back', 'BBA front', 'BBA left'],
    'BM BT': ['BM BT front', 'BM BT left'],
    'BPCL': ['BPCL front'],
    'CSE dept': ['CSE dept front', 'CSE dept right', 'CSE dept back'],
    'Electrical dept': ['Electrical dept back', 'Electrical dept front', 'Electrical dept left', 'Electrical dept right'],
    'Golden jubilee': ['Golden jubilee back', 'Golden jubilee front', 'Golden jubilee left', 'Golden jubilee right'],
    'LA1': ['LA 1 front', 'LA 1 left', 'LA 1 right'],
    'LA2': ['LA 2 back', 'LA 2 front', 'LA 2 right'],
    'Main building': ['Main building front'],
    'Mech dept': ['Mech dept back', 'Mech dept front']
}

# Augmentation functions
def apply_blur(image):
    return cv2.GaussianBlur(image, (5, 5), 0)

def apply_flip(image):
    return cv2.flip(image, 1)  # Horizontal flip

def apply_rotation(image, angle=30):
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    return cv2.warpAffine(image, matrix, (w, h))

def apply_zoom(image, zoom_factor=1.2):
    h, w = image.shape[:2]
    new_h, new_w = int(h * zoom_factor), int(w * zoom_factor)
    resized = cv2.resize(image, (new_w, new_h))
    start_h, start_w = (new_h - h) // 2, (new_w - w) // 2
    return resized[start_h:start_h + h, start_w:start_w + w]

# Save augmented images in output directory structure
def save_augmented_images(output_folder, image_name, augmentations):
    base_name = os.path.splitext(image_name)[0]
    saved_files = []
    for idx, aug_img in enumerate(augmentations):
        aug_image_name = f"{base_name}_aug_{idx + 1}.jpg"
        aug_image_path = os.path.join(output_folder, aug_image_name)
        
        # Save and collect saved file paths for logging
        if cv2.imwrite(aug_image_path, aug_img):
            saved_files.append(aug_image_path)
        else:
            print(f"Failed to save: {aug_image_path}")
    
    return saved_files

# Main function to iterate over each subfolder and apply augmentations
for category, subfolders in CATEGORIES.items():
    for subfolder in subfolders:
        input_folder_path = os.path.join(INPUT_DIR, subfolder)
        output_folder_path = os.path.join(DATADIR, subfolder)

        # Create corresponding output directory
        os.makedirs(output_folder_path, exist_ok=True)

        # Check if input subfolder exists
        if not os.path.exists(input_folder_path):
            print(f"Directory {input_folder_path} does not exist, skipping...")
            continue

        print(f"\nProcessing folder: {subfolder}\n{'=' * 30}")
        
        # Initialize list to keep track of saved images in this folder
        all_saved_files = []
        
        # Copy original images to output directory and apply augmentations
        for image_name in tqdm(os.listdir(input_folder_path)):
            if image_name.lower().endswith(('jpg', 'jpeg', 'png')):
                image_path = os.path.join(input_folder_path, image_name)
                image = cv2.imread(image_path)

                if image is None:
                    print(f"Could not read image: {image_path}")
                    continue

                # Copy original image to the output folder
                output_image_path = os.path.join(output_folder_path, image_name)
                shutil.copy(image_path, output_image_path)
                
                # Apply augmentations
                augmentations = [
                    apply_blur(image),
                    apply_flip(image),
                    apply_rotation(image, angle=randint(15, 45)),  # Rotate with a random angle
                    apply_zoom(image, zoom_factor=1.2)
                ]

                # Save augmented images in the output folder
                saved_files = save_augmented_images(output_folder_path, image_name, augmentations)
                all_saved_files.extend(saved_files)

        # Print all saved files for this folder at once
        if all_saved_files:
            print(f"\nSaved images in folder '{subfolder}':")
            for file_path in all_saved_files:
                print(file_path)
            print("\n" + "=" * 50 + "\n")

print("\nData augmentation complete. All images saved to the output directory.")
# Out:
# Processing folder: BBA back
# ==============================
# 100%|██████████| 60/60 [00:31<00:00,  1.89it/s]
# Saved images in folder 'BBA back':
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195814929_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195814929_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195814929_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195814929_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072048545_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072048545_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072048545_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072048545_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072020038_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072020038_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072020038_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072020038_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155227196_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155227196_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155227196_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155227196_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195907484_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195907484_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195907484_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195907484_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072034450_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072034450_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072034450_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072034450_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072025732_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072025732_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072025732_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072025732_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195825839_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195825839_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195825839_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195825839_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072032211_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072032211_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072032211_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072032211_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072106881_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072106881_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072106881_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072106881_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155246646_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155246646_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155246646_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155246646_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072028421_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072028421_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072028421_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072028421_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195841374_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195841374_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195841374_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195841374_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195939283_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195939283_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195939283_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195939283_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155241374_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155241374_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155241374_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155241374_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155255596_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155255596_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155255596_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155255596_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155225227_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155225227_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155225227_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155225227_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155235893_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155235893_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155235893_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155235893_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155257476_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155257476_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155257476_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155257476_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072030491_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072030491_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072030491_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072030491_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155250130_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155250130_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155250130_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155250130_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155304472_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155304472_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155304472_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155304472_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195845368_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195845368_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195845368_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195845368_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155233031_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155233031_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155233031_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155233031_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072052739_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072052739_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072052739_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072052739_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155258770_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155258770_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155258770_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155258770_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155251886_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155251886_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155251886_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155251886_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072042365_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072042365_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072042365_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072042365_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195933915_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195933915_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195933915_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195933915_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155239502_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155239502_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155239502_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155239502_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155237702_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155237702_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155237702_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155237702_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195928262_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195928262_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195928262_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195928262_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072046517_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072046517_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072046517_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072046517_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195918466_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195918466_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195918466_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195918466_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155306266_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155306266_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155306266_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155306266_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195830269_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195830269_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195830269_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195830269_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155229232_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155229232_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155229232_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155229232_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155231434_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155231434_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155231434_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155231434_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195849602_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195849602_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195849602_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195849602_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195818415_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195818415_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195818415_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195818415_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195854348_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195854348_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195854348_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195854348_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072050518_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072050518_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072050518_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072050518_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195943937_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195943937_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195943937_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195943937_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155242909_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155242909_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155242909_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155242909_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195837328_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195837328_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195837328_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195837328_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072036545_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072036545_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072036545_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072036545_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072055063_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072055063_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072055063_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072055063_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155253935_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155253935_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155253935_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155253935_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072022060_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072022060_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072022060_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072022060_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195822349_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195822349_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195822349_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195822349_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072023785_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072023785_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072023785_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072023785_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195913830_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195913830_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195913830_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195913830_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155248138_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155248138_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155248138_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20221202_155248138_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195948699_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195948699_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195948699_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195948699_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072044214_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072044214_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072044214_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072044214_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195923436_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195923436_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195923436_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195923436_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072017051_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072017051_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072017051_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072017051_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195903088_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195903088_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195903088_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230509_195903088_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072105240_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072105240_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072105240_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072105240_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072103012_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072103012_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072103012_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA back/IMG_20230311_072103012_aug_4.jpg
#
# ==================================================
#
#
# Processing folder: BBA front
# ==============================
# 100%|██████████| 40/40 [00:22<00:00,  1.77it/s]
# Saved images in folder 'BBA front':
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072530325_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072530325_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072530325_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072530325_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072521321_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072521321_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072521321_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072521321_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072532597_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072532597_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072532597_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072532597_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154937737_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154937737_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154937737_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154937737_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154953127_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154953127_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154953127_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154953127_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072506171_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072506171_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072506171_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072506171_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154927772_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154927772_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154927772_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154927772_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072509758_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072509758_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072509758_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072509758_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072527406_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072527406_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072527406_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072527406_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072501449_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072501449_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072501449_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072501449_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072512447_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072512447_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072512447_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072512447_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154925266_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154925266_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154925266_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154925266_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154956300_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154956300_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154956300_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154956300_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154913940_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154913940_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154913940_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154913940_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154944675_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154944675_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154944675_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154944675_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154947572_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154947572_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154947572_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154947572_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154923573_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154923573_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154923573_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154923573_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072526014_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072526014_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072526014_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072526014_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072515475_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072515475_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072515475_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072515475_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154930362_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154930362_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154930362_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154930362_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072504975_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072504975_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072504975_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072504975_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154942762_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154942762_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154942762_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154942762_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154918384_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154918384_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154918384_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154918384_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154939403_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154939403_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154939403_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154939403_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154951100_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154951100_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154951100_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154951100_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072507431_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072507431_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072507431_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072507431_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072519874_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072519874_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072519874_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072519874_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072511157_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072511157_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072511157_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072511157_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154911186_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154911186_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154911186_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154911186_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072522470_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072522470_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072522470_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072522470_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072523745_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072523745_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072523745_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072523745_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072518090_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072518090_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072518090_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072518090_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154949370_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154949370_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154949370_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154949370_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072503651_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072503651_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072503651_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072503651_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154941155_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154941155_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154941155_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154941155_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072528910_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072528910_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072528910_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072528910_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154920537_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154920537_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154920537_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154920537_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154915999_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154915999_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154915999_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154915999_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072513910_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072513910_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072513910_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20230311_072513910_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154932394_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154932394_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154932394_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA front/IMG_20221202_154932394_aug_4.jpg
#
# ==================================================
#
#
# Processing folder: BBA left
# ==============================
# 100%|██████████| 40/40 [00:21<00:00,  1.82it/s]
# Saved images in folder 'BBA left':
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155051521_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155051521_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155051521_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155051521_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072215832_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072215832_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072215832_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072215832_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072213788_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072213788_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072213788_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072213788_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072239245_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072239245_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072239245_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072239245_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072257144_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072257144_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072257144_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072257144_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072306804_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072306804_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072306804_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072306804_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072300265_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072300265_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072300265_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072300265_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155101122_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155101122_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155101122_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155101122_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155059543_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155059543_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155059543_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155059543_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155106729_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155106729_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155106729_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155106729_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155110522_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155110522_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155110522_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155110522_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072311400_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072311400_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072311400_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072311400_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155048367_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155048367_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155048367_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155048367_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072304588_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072304588_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072304588_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072304588_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072258835_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072258835_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072258835_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072258835_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072313243_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072313243_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072313243_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072313243_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072317857_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072317857_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072317857_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072317857_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155111746_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155111746_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155111746_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155111746_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155118209_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155118209_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155118209_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155118209_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155049894_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155049894_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155049894_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155049894_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072309043_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072309043_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072309043_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072309043_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072319943_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072319943_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072319943_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072319943_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155124105_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155124105_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155124105_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155124105_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155116051_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155116051_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155116051_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155116051_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072322263_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072322263_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072322263_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072322263_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155055648_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155055648_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155055648_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155055648_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155130242_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155130242_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155130242_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155130242_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072255204_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072255204_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072255204_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072255204_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155128133_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155128133_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155128133_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155128133_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155104804_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155104804_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155104804_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155104804_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155053583_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155053583_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155053583_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155053583_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155126058_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155126058_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155126058_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155126058_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072315509_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072315509_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072315509_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072315509_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155113495_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155113495_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155113495_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155113495_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155102681_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155102681_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155102681_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155102681_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155131970_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155131970_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155131970_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20221202_155131970_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072301760_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072301760_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072301760_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072301760_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072237320_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072237320_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072237320_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072237320_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072210935_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072210935_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072210935_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072210935_aug_4.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072324281_aug_1.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072324281_aug_2.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072324281_aug_3.jpg
# /kaggle/working/nitr-lowlight/BBA left/IMG_20230311_072324281_aug_4.jpg
#
# ==================================================
#
#
# Processing folder: BM BT front
# ==============================
# 100%|██████████| 20/20 [00:10<00:00,  1.86it/s]
# Saved images in folder 'BM BT front':
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150847156_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150847156_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150847156_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150847156_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150814113_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150814113_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150814113_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150814113_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150835695_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150835695_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150835695_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150835695_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150834296_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150834296_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150834296_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150834296_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150845614_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150845614_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150845614_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150845614_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150820113_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150820113_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150820113_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150820113_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150849655_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150849655_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150849655_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150849655_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150818368_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150818368_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150818368_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150818368_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150816039_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150816039_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150816039_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150816039_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150817804_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150817804_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150817804_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150817804_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150827122_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150827122_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150827122_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150827122_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150829452_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150829452_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150829452_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150829452_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150848303_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150848303_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150848303_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150848303_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150841105_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150841105_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150841105_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150841105_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150831477_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150831477_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150831477_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150831477_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150823570_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150823570_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150823570_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150823570_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150837625_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150837625_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150837625_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150837625_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150825364_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150825364_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150825364_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150825364_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150839317_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150839317_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150839317_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150839317_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150843871_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150843871_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150843871_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT front/IMG_20221202_150843871_aug_4.jpg
#
# ==================================================
#
#
# Processing folder: BM BT left
# ==============================
# 100%|██████████| 15/15 [00:07<00:00,  1.89it/s]
# Saved images in folder 'BM BT left':
# /kaggle/working/nitr-lowlight/BM BT left/IMG_20221202_152808405_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT left/IMG_20221202_152808405_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT left/IMG_20221202_152808405_aug_3.jpg
# /kaggle/working/nitr-lowlight/BM BT left/IMG_20221202_152808405_aug_4.jpg
# /kaggle/working/nitr-lowlight/BM BT left/IMG_20221202_152812368_aug_1.jpg
# /kaggle/working/nitr-lowlight/BM BT left/IMG_20221202_152812368_aug_2.jpg
# /kaggle/working/nitr-lowlight/BM BT left/IMG_20221202_152812368_aug_3.jpg
# ...
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152106311_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152106311_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152056386_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152056386_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152056386_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152056386_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070832588_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070832588_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070832588_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070832588_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152057881_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152057881_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152057881_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152057881_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070751894_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070751894_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070751894_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070751894_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152122459_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152122459_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152122459_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152122459_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070842253_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070842253_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070842253_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20230311_070842253_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152114532_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152114532_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152114532_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152114532_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152124158_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152124158_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152124158_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152124158_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152120483_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152120483_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152120483_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept back/IMG_20221202_152120483_aug_4.jpg
#
# ==================================================
#
#
# Processing folder: Mech dept front
# ==============================
# 100%|██████████| 40/40 [00:20<00:00,  1.93it/s]
# Saved images in folder 'Mech dept front':
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151542968_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151542968_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151542968_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151542968_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074612059_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074612059_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074612059_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074612059_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151603152_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151603152_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151603152_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151603152_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074613958_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074613958_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074613958_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074613958_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074515023_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074515023_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074515023_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074515023_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151606061_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151606061_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151606061_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151606061_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151551920_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151551920_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151551920_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151551920_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074517705_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074517705_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074517705_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074517705_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151553384_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151553384_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151553384_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151553384_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074606738_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074606738_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074606738_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074606738_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074524184_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074524184_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074524184_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074524184_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074522252_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074522252_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074522252_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074522252_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151604466_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151604466_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151604466_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151604466_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074608601_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074608601_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074608601_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074608601_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151549866_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151549866_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151549866_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151549866_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074603051_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074603051_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074603051_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074603051_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074501661_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074501661_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074501661_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074501661_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151613439_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151613439_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151613439_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151613439_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074559976_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074559976_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074559976_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074559976_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151601971_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151601971_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151601971_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151601971_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151558567_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151558567_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151558567_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151558567_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074457826_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074457826_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074457826_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074457826_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074513820_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074513820_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074513820_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074513820_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151546238_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151546238_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151546238_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151546238_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074454086_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074454086_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074454086_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074454086_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151556802_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151556802_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151556802_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151556802_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074455581_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074455581_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074455581_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074455581_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074516314_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074516314_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074516314_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074516314_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151617173_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151617173_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151617173_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151617173_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151548102_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151548102_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151548102_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151548102_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151611271_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151611271_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151611271_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151611271_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151555409_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151555409_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151555409_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151555409_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074452558_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074452558_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074452558_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074452558_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074601571_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074601571_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074601571_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074601571_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151607542_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151607542_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151607542_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151607542_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074610461_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074610461_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074610461_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074610461_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151544487_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151544487_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151544487_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151544487_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151609991_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151609991_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151609991_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151609991_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151615552_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151615552_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151615552_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20221202_151615552_aug_4.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074512136_aug_1.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074512136_aug_2.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074512136_aug_3.jpg
# /kaggle/working/nitr-lowlight/Mech dept front/IMG_20230311_074512136_aug_4.jpg
#
# ==================================================
#
#
# Data augmentation complete. All images saved to the output directory.

# %%
for category, subfolders in CATEGORIES.items():
    for subfolder in subfolders:
        path = os.path.join(DATADIR, subfolder)
        print(f"Checking path: {path}")  # Debug line to see the full path
        if os.path.exists(path):  # Check if the directory exists
            for img in os.listdir(path):
                img_path = os.path.join(path, img)
                img_array = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read the image in grayscale
                plt.imshow(img_array, cmap='gray')  # Display in grayscale
                plt.title(f"{category} - {subfolder}")
                plt.axis('off')  # Hide the axis
                plt.show()
                break  # Display only one image per subfolder
        else:
            print(f"Directory not found: {path}")
    break
# Out:
# Checking path: /kaggle/working/nitr-lowlight/BBA back
# Checking path: /kaggle/working/nitr-lowlight/BBA front
# Checking path: /kaggle/working/nitr-lowlight/BBA left

# %%
IMG_SIZE = 150

new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array, cmap = 'gray')
plt.show()

# %%
training_data = []

def create_training_data():
    for class_num, (category, subfolders) in enumerate(CATEGORIES.items()):
        for subfolder in subfolders:
            path = os.path.join(DATADIR, subfolder)
            print(f"Processing folder: {path}")  # Debug line to see which folder is being processed
            if os.path.exists(path):  # Check if the directory exists
                for img in os.listdir(path):
                    try:
                        img_path = os.path.join(path, img)
                        img_array = cv2.imread(img_path)
                        
                        if img_array is None:
                            print(f"Failed to load image: {img_path}")
                            continue  # Skip images that couldn't be loaded

                        # Convert to grayscale if the image is not already in grayscale
                        if len(img_array.shape) == 3:  # Check if it's an RGB image
                            img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2GRAY)

                        # Resize the image
                        new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                        new_array = np.expand_dims(new_array, axis=-1)

                        # Append the processed image and its class label
                        training_data.append([new_array, class_num])
                        
                    except Exception as e:
                        print(f"Error processing image {img_path}: {e}")  # Optional: print the error for debugging
            else:
                print(f"Directory not found: {path}")

create_training_data()

# Optionally, print out the number of items in training data to verify
print(f"Total training samples: {len(training_data)}")
# Out:
# Processing folder: /kaggle/working/nitr-lowlight/BBA back
# Processing folder: /kaggle/working/nitr-lowlight/BBA front
# Processing folder: /kaggle/working/nitr-lowlight/BBA left
# Processing folder: /kaggle/working/nitr-lowlight/BM BT front
# Processing folder: /kaggle/working/nitr-lowlight/BM BT left
# Processing folder: /kaggle/working/nitr-lowlight/BPCL front
# Processing folder: /kaggle/working/nitr-lowlight/CSE dept front
# Processing folder: /kaggle/working/nitr-lowlight/CSE dept right
# Processing folder: /kaggle/working/nitr-lowlight/CSE dept back
# Processing folder: /kaggle/working/nitr-lowlight/Electrical dept back
# Processing folder: /kaggle/working/nitr-lowlight/Electrical dept front
# Processing folder: /kaggle/working/nitr-lowlight/Electrical dept left
# Processing folder: /kaggle/working/nitr-lowlight/Electrical dept right
# Processing folder: /kaggle/working/nitr-lowlight/Golden jubilee back
# Processing folder: /kaggle/working/nitr-lowlight/Golden jubilee front
# Processing folder: /kaggle/working/nitr-lowlight/Golden jubilee left
# Processing folder: /kaggle/working/nitr-lowlight/Golden jubilee right
# Processing folder: /kaggle/working/nitr-lowlight/LA 1 front
# Processing folder: /kaggle/working/nitr-lowlight/LA 1 left
# Processing folder: /kaggle/working/nitr-lowlight/LA 1 right
# Processing folder: /kaggle/working/nitr-lowlight/LA 2 back
# Processing folder: /kaggle/working/nitr-lowlight/LA 2 front
# Processing folder: /kaggle/working/nitr-lowlight/LA 2 right
# Processing folder: /kaggle/working/nitr-lowlight/Main building front
# Processing folder: /kaggle/working/nitr-lowlight/Mech dept back
# Processing folder: /kaggle/working/nitr-lowlight/Mech dept front
# Total training samples: 5000

# %%
# Shuffling the training data
import random
random.shuffle(training_data)

# %%
X = []
y = []

for features, labels in training_data:
    X.append(features)
    y.append(labels)

X = np.array(X)
y = np.array(y)

# %%
X.shape
# Out:
# (5000, 150, 150, 1)

# %%
y.shape
# Out:
# (5000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (4000, 150, 150, 1)

# %%
y_train.shape
# Out:
# (4000,)

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
X_train.shape
# Out:
# (4000, 150, 150, 1)

# %%
num_classes=10

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
from tensorflow.keras.layers import Layer, Softmax, Conv2D
from tensorflow.keras import backend as K

from tensorflow.keras.layers import Layer, Softmax, Conv2D, Reshape, Add

class SelfAttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(SelfAttentionLayer, self).__init__(**kwargs)
        # Define all Conv2D layers here to avoid reinitializing them on each call
        self.theta_conv = Conv2D(128, kernel_size=(1,1), padding='same')
        self.phi_conv = Conv2D(128, kernel_size=(1,1), padding='same')
        self.g_conv = Conv2D(128, kernel_size=(1,1), padding='same')
        self.output_conv = Conv2D(256, kernel_size=(1,1), padding='same')
        self.input_proj_conv = Conv2D(256, kernel_size=(1,1), padding='same')
        self.softmax = Softmax()

    def call(self, inputs):
        h, w, c = inputs.shape[1], inputs.shape[2], inputs.shape[3]
        
        # Theta (query)
        theta = self.theta_conv(inputs)
        theta_rsh = Reshape((h * w, 128))(theta)

        # Phi (key)
        phi = self.phi_conv(inputs)
        phi_rsh = Reshape((h * w, 128))(phi)

        # G (value)
        g = self.g_conv(inputs)
        g_rsh = Reshape((h * w, 128))(g)

        # Self-attention using K.batch_dot
        theta_phi = K.batch_dot(theta_rsh, phi_rsh, axes=[2, 2])
        theta_phi = self.softmax(theta_phi)

        # Weighted sum
        theta_phi_g = K.batch_dot(theta_phi, g_rsh)
        theta_phi_g = Reshape((h, w, 128))(theta_phi_g)

        # Final convolution to adjust the channel dimension
        theta_phi_g = self.output_conv(theta_phi_g)

        # Project inputs to match the channel dimensions of theta_phi_g for addition
        inputs_proj = self.input_proj_conv(inputs)

        # Add residual connection
        output_tensor = Add()([theta_phi_g, inputs_proj])
        return output_tensor


# Now, integrate this into the proposed model function
def proposed_model(input_shape=X_train.shape[1:], num_classes=10):
    inputs = Input(shape=input_shape)
    
    # First Convolutional Block
    x = Conv2D(filters=64, kernel_size=(3, 3), padding='Same', activation='relu', kernel_regularizer=l2(0.01))(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Second Convolutional Block
    x = Conv2D(filters=128, kernel_size=(3, 3), padding='Same', activation='relu', kernel_regularizer=l2(0.01))(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Third Convolutional Block
    x = Conv2D(filters=128, kernel_size=(3, 3), padding='Same', activation='relu', kernel_regularizer=l2(0.01))(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Apply Self-Attention after the third block
    x = SelfAttentionLayer()(x)

    # Fourth Convolutional Block
    x = Conv2D(filters=128, kernel_size=(2, 2), padding='Same', activation='relu', kernel_regularizer=l2(0.01))(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Fifth Convolutional Block
    x = Conv2D(filters=256, kernel_size=(2, 2), padding='Same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = Dropout(0.3)(x)

    # Fully Connected Layers
    x = Flatten()(x)
    x = Dense(1024, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = Dropout(0.5)(x)

    # Output Layer
    outputs = Dense(num_classes, activation='softmax')(x)
    
    # Create Model
    model = Model(inputs=inputs, outputs=outputs)
    
    # Compile Model
    optimizer = Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# # Function to build models with pre-trained architectures
# def pretrained_model(base_model, input_shape=X_train.shape[1:], num_classes=10):
#     input_tensor = Input(shape=input_shape)
#     x = tf.keras.layers.Concatenate()([input_tensor, input_tensor, input_tensor])  # Convert grayscale to 3 channels
#     base_model = base_model(include_top=False, weights='imagenet', input_tensor=x)
#     x = base_model.output
#     x = GlobalAveragePooling2D()(x)
#     x = Dense(1024, activation='relu')(x)
#     x = Dropout(0.5)(x)
#     predictions = Dense(num_classes, activation='softmax')(x)
#     model = Model(inputs=input_tensor, outputs=predictions)

#     for layer in base_model.layers:
#         layer.trainable = False
        
#     optimizer = Adam(learning_rate=0.0001)
#     model.compile(optimizer='adam', loss = CategoricalCrossentropy, metrics=['accuracy'])
#     return model

# %%
models = {
    'Proposed': proposed_model()
    # 'DenseNet121': pretrained_model(DenseNet121),
    # 'ResNet50': pretrained_model(ResNet50),
    # 'VGG16': pretrained_model(VGG16),
    # 'EfficientNetB7': pretrained_model(EfficientNetB7),
    # 'InceptionV3': pretrained_model(InceptionV3)
}
history_dict = {}

# %%
models['Proposed'].summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 150, 150, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 150, 150, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ self_attention_layer            │ (None, 18, 18, 256)    │       115,584 │
# │ (SelfAttentionLayer)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 18, 18, 128)    │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 9, 9, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 9, 9, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 9, 9, 256)      │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     4,195,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,805,770 (18.33 MB)
#  Trainable params: 4,805,770 (18.33 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
for model_name, model in models.items():
    print(f"Training {model_name} Model : ")
    
    history = model.fit(X_train, y_train, 
        batch_size=32,  
        validation_data=(X_test, y_test),
        epochs=100,
    )
    
    history_dict[model_name] = history.history
# Out:
# Training Proposed Model :
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 63ms/step - accuracy: 0.1700 - loss: 19.4652 - val_accuracy: 0.1890 - val_loss: 12.1788
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.2040 - loss: 10.5515 - val_accuracy: 0.2910 - val_loss: 7.0754
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.3104 - loss: 6.2441 - val_accuracy: 0.3090 - val_loss: 4.7521
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.3534 - loss: 4.3164 - val_accuracy: 0.3740 - val_loss: 3.6137
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.3871 - loss: 3.3665 - val_accuracy: 0.3700 - val_loss: 3.0403
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4093 - loss: 2.8375 - val_accuracy: 0.4160 - val_loss: 2.6679
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4439 - loss: 2.5144 - val_accuracy: 0.4300 - val_loss: 2.3895
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.4593 - loss: 2.2852 - val_accuracy: 0.4550 - val_loss: 2.2253
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.4894 - loss: 2.0933 - val_accuracy: 0.5220 - val_loss: 2.0509
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5312 - loss: 1.9606 - val_accuracy: 0.5590 - val_loss: 1.9115
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5742 - loss: 1.8020 - val_accuracy: 0.5720 - val_loss: 1.8379
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5834 - loss: 1.7479 - val_accuracy: 0.5910 - val_loss: 1.7531
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.6173 - loss: 1.6430 - val_accuracy: 0.6250 - val_loss: 1.6855
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.6486 - loss: 1.5718 - val_accuracy: 0.6350 - val_loss: 1.6542
# Epoch 15/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.6795 - loss: 1.4785 - val_accuracy: 0.6380 - val_loss: 1.6293
# Epoch 16/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.7025 - loss: 1.4111 - val_accuracy: 0.6970 - val_loss: 1.5190
# Epoch 17/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.7283 - loss: 1.3659 - val_accuracy: 0.6830 - val_loss: 1.5289
# Epoch 18/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.7380 - loss: 1.3406 - val_accuracy: 0.7160 - val_loss: 1.4831
# Epoch 19/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.7769 - loss: 1.2427 - val_accuracy: 0.7000 - val_loss: 1.4689
# Epoch 20/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.7839 - loss: 1.2310 - val_accuracy: 0.7520 - val_loss: 1.3420
# Epoch 21/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.7943 - loss: 1.1987 - val_accuracy: 0.7130 - val_loss: 1.4571
# Epoch 22/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8262 - loss: 1.1228 - val_accuracy: 0.7840 - val_loss: 1.3169
# Epoch 23/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8356 - loss: 1.1170 - val_accuracy: 0.7830 - val_loss: 1.2833
# Epoch 24/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.8584 - loss: 1.0430 - val_accuracy: 0.7500 - val_loss: 1.3528
# Epoch 25/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.8475 - loss: 1.0414 - val_accuracy: 0.8020 - val_loss: 1.2649
# Epoch 26/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8766 - loss: 0.9771 - val_accuracy: 0.8210 - val_loss: 1.1958
# Epoch 27/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.8737 - loss: 0.9750 - val_accuracy: 0.8390 - val_loss: 1.1536
# Epoch 28/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9002 - loss: 0.9210 - val_accuracy: 0.8400 - val_loss: 1.1579
# Epoch 29/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8813 - loss: 0.9480 - val_accuracy: 0.8270 - val_loss: 1.1776
# Epoch 30/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9119 - loss: 0.8802 - val_accuracy: 0.8420 - val_loss: 1.1151
# Epoch 31/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9142 - loss: 0.8901 - val_accuracy: 0.8420 - val_loss: 1.1154
# Epoch 32/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9105 - loss: 0.8851 - val_accuracy: 0.8200 - val_loss: 1.1444
# Epoch 33/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9089 - loss: 0.8635 - val_accuracy: 0.8550 - val_loss: 1.0580
# Epoch 34/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9242 - loss: 0.8310 - val_accuracy: 0.8590 - val_loss: 1.0489
# Epoch 35/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9260 - loss: 0.8095 - val_accuracy: 0.8600 - val_loss: 1.0163
# Epoch 36/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9357 - loss: 0.7829 - val_accuracy: 0.8420 - val_loss: 1.0422
# Epoch 37/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9369 - loss: 0.7600 - val_accuracy: 0.8620 - val_loss: 0.9925
# Epoch 38/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9363 - loss: 0.7501 - val_accuracy: 0.8650 - val_loss: 1.0006
# Epoch 39/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9407 - loss: 0.7316 - val_accuracy: 0.8710 - val_loss: 0.9809
# Epoch 40/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9294 - loss: 0.7594 - val_accuracy: 0.8610 - val_loss: 1.0102
# Epoch 41/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9379 - loss: 0.7423 - val_accuracy: 0.8810 - val_loss: 0.9459
# Epoch 42/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9430 - loss: 0.7232 - val_accuracy: 0.8700 - val_loss: 0.9571
# Epoch 43/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9476 - loss: 0.7036 - val_accuracy: 0.8730 - val_loss: 0.9728
# Epoch 44/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.9468 - loss: 0.7201 - val_accuracy: 0.8730 - val_loss: 0.9581
# Epoch 45/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9421 - loss: 0.7129 - val_accuracy: 0.8790 - val_loss: 0.9340
# Epoch 46/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9444 - loss: 0.6993 - val_accuracy: 0.8800 - val_loss: 0.9235
# Epoch 47/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9599 - loss: 0.6768 - val_accuracy: 0.8760 - val_loss: 0.9272
# Epoch 48/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9448 - loss: 0.6958 - val_accuracy: 0.8840 - val_loss: 0.8829
# Epoch 49/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9566 - loss: 0.6626 - val_accuracy: 0.8710 - val_loss: 0.9322
# Epoch 50/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9496 - loss: 0.6874 - val_accuracy: 0.8810 - val_loss: 0.8924
# Epoch 51/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9569 - loss: 0.6651 - val_accuracy: 0.8880 - val_loss: 0.8836
# Epoch 52/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9509 - loss: 0.6731 - val_accuracy: 0.8820 - val_loss: 0.9282
# Epoch 53/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9483 - loss: 0.6630 - val_accuracy: 0.8990 - val_loss: 0.8629
# Epoch 54/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9584 - loss: 0.6534 - val_accuracy: 0.8850 - val_loss: 0.8723
# Epoch 55/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9564 - loss: 0.6507 - val_accuracy: 0.8800 - val_loss: 0.8898
# Epoch 56/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9519 - loss: 0.6549 - val_accuracy: 0.8880 - val_loss: 0.8781
# Epoch 57/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9599 - loss: 0.6399 - val_accuracy: 0.8990 - val_loss: 0.8377
# Epoch 58/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9652 - loss: 0.6157 - val_accuracy: 0.9040 - val_loss: 0.8349
# Epoch 59/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9660 - loss: 0.6049 - val_accuracy: 0.8990 - val_loss: 0.8371
# Epoch 60/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9588 - loss: 0.6230 - val_accuracy: 0.8820 - val_loss: 0.9006
# Epoch 61/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9606 - loss: 0.6171 - val_accuracy: 0.8880 - val_loss: 0.8549
# Epoch 62/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9527 - loss: 0.6195 - val_accuracy: 0.8860 - val_loss: 0.8548
# Epoch 63/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9548 - loss: 0.6399 - val_accuracy: 0.8920 - val_loss: 0.8281
# Epoch 64/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9587 - loss: 0.6106 - val_accuracy: 0.9030 - val_loss: 0.7814
# Epoch 65/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.9603 - loss: 0.6153 - val_accuracy: 0.8920 - val_loss: 0.8541
# Epoch 66/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9657 - loss: 0.5900 - val_accuracy: 0.8960 - val_loss: 0.8394
# Epoch 67/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9688 - loss: 0.5908 - val_accuracy: 0.9030 - val_loss: 0.7889
# Epoch 68/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9669 - loss: 0.5718 - val_accuracy: 0.8970 - val_loss: 0.8009
# Epoch 69/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9703 - loss: 0.5681 - val_accuracy: 0.8990 - val_loss: 0.7870
# Epoch 70/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9647 - loss: 0.5758 - val_accuracy: 0.9070 - val_loss: 0.7959
# Epoch 71/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9691 - loss: 0.5601 - val_accuracy: 0.8920 - val_loss: 0.8094
# Epoch 72/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9648 - loss: 0.5835 - val_accuracy: 0.9030 - val_loss: 0.7564
# Epoch 73/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9629 - loss: 0.5708 - val_accuracy: 0.9070 - val_loss: 0.7537
# Epoch 74/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9688 - loss: 0.5627 - val_accuracy: 0.8950 - val_loss: 0.7923
# Epoch 75/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9612 - loss: 0.5642 - val_accuracy: 0.9040 - val_loss: 0.7644
# Epoch 76/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9642 - loss: 0.5566 - val_accuracy: 0.9060 - val_loss: 0.7761
# Epoch 77/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9640 - loss: 0.5620 - val_accuracy: 0.8990 - val_loss: 0.7796
# Epoch 78/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9655 - loss: 0.5595 - val_accuracy: 0.9040 - val_loss: 0.7582
# Epoch 79/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9746 - loss: 0.5447 - val_accuracy: 0.9110 - val_loss: 0.7514
# Epoch 80/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9662 - loss: 0.5636 - val_accuracy: 0.9090 - val_loss: 0.7605
# Epoch 81/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9728 - loss: 0.5435 - val_accuracy: 0.9110 - val_loss: 0.7297
# Epoch 82/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9646 - loss: 0.5600 - val_accuracy: 0.9130 - val_loss: 0.7277
# Epoch 83/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9694 - loss: 0.5410 - val_accuracy: 0.9080 - val_loss: 0.7234
# Epoch 84/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9726 - loss: 0.5248 - val_accuracy: 0.9010 - val_loss: 0.7364
# Epoch 85/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9756 - loss: 0.5229 - val_accuracy: 0.9050 - val_loss: 0.7318
# Epoch 86/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9679 - loss: 0.5348 - val_accuracy: 0.8880 - val_loss: 0.7686
# Epoch 87/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9689 - loss: 0.5342 - val_accuracy: 0.9100 - val_loss: 0.7436
# Epoch 88/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9637 - loss: 0.5394 - val_accuracy: 0.8990 - val_loss: 0.7655
# Epoch 89/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9779 - loss: 0.5208 - val_accuracy: 0.8960 - val_loss: 0.7523
# Epoch 90/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9760 - loss: 0.5135 - val_accuracy: 0.9060 - val_loss: 0.7313
# Epoch 91/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9722 - loss: 0.5244 - val_accuracy: 0.8760 - val_loss: 0.8104
# Epoch 92/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9485 - loss: 0.5863 - val_accuracy: 0.8830 - val_loss: 0.7701
# Epoch 93/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9725 - loss: 0.5194 - val_accuracy: 0.9040 - val_loss: 0.7394
# Epoch 94/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9611 - loss: 0.5317 - val_accuracy: 0.9140 - val_loss: 0.6897
# Epoch 95/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9730 - loss: 0.5169 - val_accuracy: 0.8990 - val_loss: 0.7327
# Epoch 96/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9671 - loss: 0.5375 - val_accuracy: 0.9130 - val_loss: 0.7085
# Epoch 97/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9690 - loss: 0.5171 - val_accuracy: 0.9090 - val_loss: 0.7093
# Epoch 98/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9768 - loss: 0.5012 - val_accuracy: 0.8890 - val_loss: 0.7669
# Epoch 99/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9743 - loss: 0.5036 - val_accuracy: 0.9000 - val_loss: 0.7404
# Epoch 100/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.9815 - loss: 0.4834 - val_accuracy: 0.9090 - val_loss: 0.6967

# %%
import matplotlib.pyplot as plt

# Iterate through each model's history
for model_name, history in history_dict.items():
    # Extract history metrics
    acc = history['accuracy']
    val_acc = history['val_accuracy']
    loss = history['loss']
    val_loss = history['val_loss']
    
    # Create a new figure
    plt.figure(figsize=(12, 6))
    
    # Plot training and validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(range(len(acc)), acc, label='Training Accuracy')
    plt.plot(range(len(val_acc)), val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title(f'Training and Validation Accuracy - {model_name}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    
    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(range(len(loss)), loss, label='Training Loss')
    plt.plot(range(len(val_loss)), val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title(f'Training and Validation Loss - {model_name}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    
    plt.tight_layout()
    plt.show()

# %%
# Iterate through each model's history
for model_name, history in history_dict.items():
    # Extract history metrics
    acc = history['accuracy']
    val_acc = history['val_accuracy']
    loss = history['loss']
    val_loss = history['val_loss']
    
    # Calculate final metrics
    Accuracy_Score = round(acc[-1] * 100, 2)
    Validation_Score = round(val_acc[-1] * 100, 2)
    Loss_score = round(loss[-1], 2)
    Validation_loss = round(val_loss[-1], 2)
    
    # Print metrics
    print(f"Model: {model_name}")
    print(f"The Accuracy for the model is: {Accuracy_Score}%")
    print(f"The Validation Accuracy for the model is: {Validation_Score}%")
    print(f"The Loss for the model is: {Loss_score}")
    print(f"The Validation Loss for the model is: {Validation_loss}\n")
# Out:
# Model: Proposed
# The Accuracy for the model is: 97.75%
# The Validation Accuracy for the model is: 90.9%
# The Loss for the model is: 0.49
# The Validation Loss for the model is: 0.7

# %%
# Flatten categories and subfolders for easier indexing
flat_categories = {i: (category, subfolder) for i, (category, subfolders) in enumerate(CATEGORIES.items()) for subfolder in subfolders}

# Function to map subcategory predictions to main categories
def map_to_main_category(predicted_label):
    for main_category, subcategories in CATEGORIES.items():
        if predicted_label in subcategories:
            return main_category
    return None

# Function to shuffle the test data and labels
def shuffle_test_data(X, y):
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)  # Shuffle the indices
    return X[indices], y[indices]

# Iterate over models and make predictions on the test set
for model_name, model in models.items():
    # Shuffle X_test and y_test before each evaluation
    X_test_shuffled, y_test_shuffled = shuffle_test_data(X_test, y_test)
    
    # Predict on shuffled test set
    predictions = model.predict(X_test_shuffled)
    
    # Convert predictions to class labels
    predicted_classes = np.argmax(predictions, axis=1)
    
    # Convert y_test to class labels if it's one-hot encoded
    true_classes = np.argmax(y_test_shuffled, axis=1) if len(y_test_shuffled.shape) > 1 else y_test_shuffled

    # Print model name
    print(f"\nModel: {model_name}")
    
    # Display predictions and true labels for the first 10 shuffled test images
    plt.figure(figsize=(15, 15))
    for i in range(10):
        img_display = X_test_shuffled[i]
        
        # Grayscale images - no need to convert to RGB
        plt.subplot(2, 5, i + 1)
        plt.imshow(img_display, cmap='gray')  # Display as grayscale
        
        # Get predicted and true labels, map subcategory to main category
        predicted_label = flat_categories[predicted_classes[i]][1]  # Get subcategory name
        predicted_main_category = map_to_main_category(predicted_label)  # Map subcategory to main category
        
        true_label = flat_categories[true_classes[i]][1]  # Get true subcategory name
        true_main_category = map_to_main_category(true_label)  # Map true subcategory to main category
        
        # Display predicted and true main categories
        plt.title(f"Pred: {predicted_main_category}\nTrue: {true_main_category}")
        plt.axis('off')
    
    plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
#
# Model: Proposed

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.metrics import ConfusionMatrixDisplay, precision_score, recall_score

# Function to calculate ACC, SEN, and SPE from confusion matrix
def calculate_metrics(cm):
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]
    TP = cm[1, 1]
    
    ACC = (TN + TP) / (TN + TP + FN + FP) if (TN + TP + FN + FP) > 0 else float('nan')
    SEN = TP / (TP + FN) if (TP + FN) > 0 else float('nan')
    SPE = TN / (TN + FP) if (TN + FP) > 0 else float('nan')
    
    return ACC, SEN, SPE

# Assuming X_test and y_test are your test data and true labels

for model_name, model in models.items():
    # Make predictions on the test set
    predictions = model.predict(X_test)
    
    # Convert predictions to class labels if necessary
    predicted_classes = predictions.argmax(axis=1)
    
    # Convert y_test to class labels if necessary
    true_classes = y_test.argmax(axis=1) if len(y_test.shape) > 1 else y_test
    
    # Compute confusion matrix
    cm = confusion_matrix(true_classes, predicted_classes)
    
    # Calculate metrics
    ACC, SEN, SPE = calculate_metrics(cm)
    
    # Compute AUC and ROC curve
    try:
        y_pred_prob = predictions[:, 1]  # Predicted probabilities for the positive class
        AUC = roc_auc_score(true_classes, y_pred_prob)
        
        # Calculate ROC curve
        fpr, tpr, _ = roc_curve(true_classes, y_pred_prob)
        roc_auc = auc(fpr, tpr)
        
        # Plot ROC Curve
        plt.figure()
        plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f"ROC Curve for {model_name}")
        plt.legend(loc="lower right")
        plt.show()
        
    except ValueError:
        AUC = float('nan')  # Handle case where AUC calculation is not possible
        print(f"ROC Curve for {model_name} could not be computed due to invalid predictions.")
    
    # Calculate precision and recall
    precision = precision_score(true_classes, predicted_classes, average='weighted')
    recall = recall_score(true_classes, predicted_classes, average='weighted')
    
    # Print metrics
    print(f"Model: {model_name}")
    print(f"ACC: {ACC:.2f}")
    print(f"SEN: {SEN:.2f}")
    print(f"SPE: {SPE:.2f}")
    print(f"AUC: {AUC:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print("\n")
    
    # Plot confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(true_classes))
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f"Confusion Matrix for {model_name}")
    plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ROC Curve for Proposed could not be computed due to invalid predictions.
# Model: Proposed
# ACC: 1.00
# SEN: 1.00
# SPE: 1.00
# AUC: nan
# Precision: 0.91
# Recall: 0.91

# %%
# save_dir = '/kaggle/working/'
# if not os.path.exists(save_dir):
#     os.makedirs(save_dir)

# %%
# for model_name, model in models.items():
#     model_save_path = os.path.join(save_dir, f'{model_name}.h5')
#     model.save(model_save_path)
#     print(f"Model {model_name} saved at {model_save_path}")
